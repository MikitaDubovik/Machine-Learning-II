# %%
import h5py
import numpy as np
# %tensorflow_version 2.x
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
def read_hdf5(path):
    with h5py.File(path, 'r') as hf:
        return np.array(hf["X"]), np.array(hf["Y"])

# %%
def train_conv(x_train,y_train,epochs,img_height,img_width,save_path):
    model=tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(8,(3,3),activation='relu',input_shape=(img_height, img_width,1)),
        tf.keras.layers.Conv2D(16,(3,3),activation='relu'),
        tf.keras.layers.Flatten(),        
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    
    model.fit(x_train, y_train, epochs=epochs)
    model.save(save_path)

# %%
def train_conv_pool(x_train,y_train,epochs,img_height,img_width,save_path):
    model=tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(8,(3,3),activation='relu',input_shape=(img_height, img_width,1)),
        tf.keras.layers.AveragePooling2D(),
        tf.keras.layers.Flatten(),        
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    
    model.fit(x_train, y_train, epochs=epochs)
    model.save(save_path)

# %%
def train_LeNet5(x_train,y_train,epochs,save_path):
    model=tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32,32,1)),
        tf.keras.layers.AveragePooling2D(),
        tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), activation='relu'),
        tf.keras.layers.AveragePooling2D(),
        tf.keras.layers.Flatten(),        
        tf.keras.layers.Dense(120, activation='relu'),
        tf.keras.layers.Dense(84, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    
    model.fit(x_train, y_train, epochs=epochs)
    model.save(save_path)

# %%
def add_pad(X,pad):
    return np.pad(X,((0,0),(pad,pad),(pad,pad),(0,0)),mode='constant', constant_values=(0,0))

# %%
def evaluate(model_path, x_train, x_test, y_train, y_test, model_name):
    model = tf.keras.models.load_model(model_path)
    print("Evalute ",model_name)
    print("Evalute on train set")
    model.evaluate(x_train, y_train)
    print("Evalute on test set")
    model.evaluate(x_test, y_test)

# %%
img_height=img_width=28
epochs=50
pad=2

model_dict={
    "conv_model":"/content/drive/My Drive/Colab Notebooks/lab3_results/train_conv.h5",
    "conv_pool_model":"/content/drive/My Drive/Colab Notebooks/lab3_results/train_conv_pool.h5",
    "LeNet5_model":"/content/drive/My Drive/Colab Notebooks/lab3_results/train_LeNet5.h5"
    }

X,Y=read_hdf5("/content/drive/My Drive/Colab Notebooks/storage/dataset_notMNIST_large.hdf5")
X=np.reshape(X,(X.shape[0], X.shape[1], X.shape[2],1))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.05, random_state=42)

train_conv(X_train,Y_train,epochs,img_height,img_width,model_dict["conv_model"])
evaluate(model_dict["conv_model"], X_train, X_test, Y_train, Y_test, "conv_model")

train_conv_pool(X_train, Y_train,epochs,img_height,img_width,model_dict["conv_pool_model"])
evaluate(model_dict["conv_pool_model"], X_train, X_test, Y_train, Y_test, "conv_pool_model")

X_train=add_pad(X_train,pad)
X_test=add_pad(X_test,pad)
train_LeNet5(X_train,Y_train,epochs,model_dict["LeNet5_model"])
evaluate(model_dict["LeNet5_model"], X_train, X_test, Y_train, Y_test, "LeNet5_model")
# Out:
# Epoch 1/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.3318 - accuracy: 0.9006
# Epoch 2/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.2388 - accuracy: 0.9270
# Epoch 3/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.1904 - accuracy: 0.9406
# Epoch 4/50
# 15709/15709 [==============================] - 72s 5ms/step - loss: 0.1516 - accuracy: 0.9521
# Epoch 5/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.1202 - accuracy: 0.9615
# Epoch 6/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0976 - accuracy: 0.9683
# Epoch 7/50
# 15709/15709 [==============================] - 77s 5ms/step - loss: 0.0815 - accuracy: 0.9736
# Epoch 8/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0694 - accuracy: 0.9777
# Epoch 9/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0620 - accuracy: 0.9797
# Epoch 10/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0562 - accuracy: 0.9821
# Epoch 11/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0514 - accuracy: 0.9837
# Epoch 12/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0480 - accuracy: 0.9848
# Epoch 13/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0451 - accuracy: 0.9857
# Epoch 14/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0425 - accuracy: 0.9866
# Epoch 15/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0405 - accuracy: 0.9873
# Epoch 16/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0386 - accuracy: 0.9879
# Epoch 17/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0370 - accuracy: 0.9885
# Epoch 18/50
# 15709/15709 [==============================] - 72s 5ms/step - loss: 0.0358 - accuracy: 0.9890
# Epoch 19/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0348 - accuracy: 0.9892
# Epoch 20/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0332 - accuracy: 0.9898
# Epoch 21/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0325 - accuracy: 0.9900
# Epoch 22/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.0312 - accuracy: 0.9904
# Epoch 23/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.0310 - accuracy: 0.9905
# Epoch 24/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0303 - accuracy: 0.9906
# Epoch 25/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.0303 - accuracy: 0.9908
# Epoch 26/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.0294 - accuracy: 0.9909
# Epoch 27/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0284 - accuracy: 0.9914
# Epoch 28/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0280 - accuracy: 0.9915
# Epoch 29/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0285 - accuracy: 0.9914
# Epoch 30/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0275 - accuracy: 0.9918
# Epoch 31/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0271 - accuracy: 0.9919
# Epoch 32/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0262 - accuracy: 0.9920
# Epoch 33/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0261 - accuracy: 0.9920
# Epoch 34/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.0264 - accuracy: 0.9920
# Epoch 35/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0255 - accuracy: 0.9924
# Epoch 36/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0254 - accuracy: 0.9923
# Epoch 37/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0255 - accuracy: 0.9924
# Epoch 38/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0251 - accuracy: 0.9925
# Epoch 39/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0252 - accuracy: 0.9924
# Epoch 40/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0252 - accuracy: 0.9926
# Epoch 41/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0246 - accuracy: 0.9928
# Epoch 42/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0237 - accuracy: 0.9928
# Epoch 43/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0242 - accuracy: 0.9927
# Epoch 44/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0241 - accuracy: 0.9930
# Epoch 45/50
# 15709/15709 [==============================] - 76s 5ms/step - loss: 0.0238 - accuracy: 0.9930
# Epoch 46/50
# 15709/15709 [==============================] - 73s 5ms/step - loss: 0.0236 - accuracy: 0.9930
# Epoch 47/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0236 - accuracy: 0.9930
# Epoch 48/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0241 - accuracy: 0.9930
# Epoch 49/50
# 15709/15709 [==============================] - 75s 5ms/step - loss: 0.0232 - accuracy: 0.9932
# Epoch 50/50
# 15709/15709 [==============================] - 74s 5ms/step - loss: 0.0230 - accuracy: 0.9932
# Evalute  conv_model
# Evalute on train set
# 15709/15709 [==============================] - 44s 3ms/step - loss: 0.0190 - accuracy: 0.9941
# Evalute on test set
# 827/827 [==============================] - 2s 3ms/step - loss: 1.1447 - accuracy: 0.9248
# Epoch 1/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.3865 - accuracy: 0.8860
# Epoch 2/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.2895 - accuracy: 0.9127
# Epoch 3/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.2594 - accuracy: 0.9211
# Epoch 4/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.2394 - accuracy: 0.9268
# Epoch 5/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.2239 - accuracy: 0.9315
# Epoch 6/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.2110 - accuracy: 0.9347
# Epoch 7/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.2000 - accuracy: 0.9381
# Epoch 8/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1901 - accuracy: 0.9411
# Epoch 9/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1812 - accuracy: 0.9435
# Epoch 10/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.1723 - accuracy: 0.9462
# Epoch 11/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1654 - accuracy: 0.9479
# Epoch 12/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1582 - accuracy: 0.9505
# Epoch 13/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.1517 - accuracy: 0.9518
# Epoch 14/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1457 - accuracy: 0.9539
# Epoch 15/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1404 - accuracy: 0.9556
# Epoch 16/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.1346 - accuracy: 0.9571
# Epoch 17/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1302 - accuracy: 0.9585
# Epoch 18/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1259 - accuracy: 0.9598
# Epoch 19/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.1214 - accuracy: 0.9610
# Epoch 20/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1177 - accuracy: 0.9622
# Epoch 21/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1134 - accuracy: 0.9634
# Epoch 22/50
# 15709/15709 [==============================] - 53s 3ms/step - loss: 0.1098 - accuracy: 0.9647
# Epoch 23/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.1066 - accuracy: 0.9655
# Epoch 24/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.1034 - accuracy: 0.9665
# Epoch 25/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.1003 - accuracy: 0.9673
# Epoch 26/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0973 - accuracy: 0.9683
# Epoch 27/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0947 - accuracy: 0.9693
# Epoch 28/50
# 15709/15709 [==============================] - 53s 3ms/step - loss: 0.0922 - accuracy: 0.9698
# Epoch 29/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0895 - accuracy: 0.9709
# Epoch 30/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0876 - accuracy: 0.9715
# Epoch 31/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0849 - accuracy: 0.9722
# Epoch 32/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0833 - accuracy: 0.9728
# Epoch 33/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0816 - accuracy: 0.9734
# Epoch 34/50
# 15709/15709 [==============================] - 53s 3ms/step - loss: 0.0796 - accuracy: 0.9739
# Epoch 35/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0777 - accuracy: 0.9746
# Epoch 36/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0763 - accuracy: 0.9751
# Epoch 37/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0748 - accuracy: 0.9757
# Epoch 38/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0732 - accuracy: 0.9759
# Epoch 39/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0714 - accuracy: 0.9767
# Epoch 40/50
# 15709/15709 [==============================] - 53s 3ms/step - loss: 0.0702 - accuracy: 0.9773
# Epoch 41/50
# 15709/15709 [==============================] - 50s 3ms/step - loss: 0.0691 - accuracy: 0.9773
# Epoch 42/50
# 15709/15709 [==============================] - 50s 3ms/step - loss: 0.0674 - accuracy: 0.9779
# Epoch 43/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0663 - accuracy: 0.9783
# Epoch 44/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0652 - accuracy: 0.9786
# Epoch 45/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0642 - accuracy: 0.9790
# Epoch 46/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0633 - accuracy: 0.9794
# Epoch 47/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0622 - accuracy: 0.9797
# Epoch 48/50
# 15709/15709 [==============================] - 51s 3ms/step - loss: 0.0614 - accuracy: 0.9801
# Epoch 49/50
# 15709/15709 [==============================] - 52s 3ms/step - loss: 0.0605 - accuracy: 0.9803
# Epoch 50/50
# 15709/15709 [==============================] - 50s 3ms/step - loss: 0.0591 - accuracy: 0.9808
# Evalute  conv_pool_model
# Evalute on train set
# 15709/15709 [==============================] - 40s 3ms/step - loss: 0.0491 - accuracy: 0.9841
# Evalute on test set
# 827/827 [==============================] - 2s 3ms/step - loss: 0.7477 - accuracy: 0.9173
# Epoch 1/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.3572 - accuracy: 0.8919
# Epoch 2/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.2723 - accuracy: 0.9156
# Epoch 3/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.2488 - accuracy: 0.9221
# Epoch 4/50
# 15709/15709 [==============================] - 60s 4ms/step - loss: 0.2343 - accuracy: 0.9265
# Epoch 5/50
# 15709/15709 [==============================] - 60s 4ms/step - loss: 0.2238 - accuracy: 0.9292
# Epoch 6/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.2160 - accuracy: 0.9315
# Epoch 7/50
# 15709/15709 [==============================] - 59s 4ms/step - loss: 0.2091 - accuracy: 0.9334
# Epoch 8/50
# 15709/15709 [==============================] - 60s 4ms/step - loss: 0.2039 - accuracy: 0.9348
# Epoch 9/50
# 15709/15709 [==============================] - 60s 4ms/step - loss: 0.1995 - accuracy: 0.9360
# Epoch 10/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1949 - accuracy: 0.9373
# Epoch 11/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1915 - accuracy: 0.9383
# Epoch 12/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1881 - accuracy: 0.9392
# Epoch 13/50
# 15709/15709 [==============================] - 64s 4ms/step - loss: 0.1847 - accuracy: 0.9402
# Epoch 14/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1822 - accuracy: 0.9410
# Epoch 15/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1794 - accuracy: 0.9415
# Epoch 16/50
# 15709/15709 [==============================] - 64s 4ms/step - loss: 0.1770 - accuracy: 0.9422
# Epoch 17/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1746 - accuracy: 0.9429
# Epoch 18/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1724 - accuracy: 0.9436
# Epoch 19/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1709 - accuracy: 0.9438
# Epoch 20/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1686 - accuracy: 0.9447
# Epoch 21/50
# 15709/15709 [==============================] - 64s 4ms/step - loss: 0.1674 - accuracy: 0.9447
# Epoch 22/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1660 - accuracy: 0.9451
# Epoch 23/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1647 - accuracy: 0.9459
# Epoch 24/50
# 15709/15709 [==============================] - 60s 4ms/step - loss: 0.1625 - accuracy: 0.9465
# Epoch 25/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1610 - accuracy: 0.9468
# Epoch 26/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1598 - accuracy: 0.9473
# Epoch 27/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1588 - accuracy: 0.9474
# Epoch 28/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1575 - accuracy: 0.9476
# Epoch 29/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1562 - accuracy: 0.9481
# Epoch 30/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1554 - accuracy: 0.9481
# Epoch 31/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1540 - accuracy: 0.9484
# Epoch 32/50
# 15709/15709 [==============================] - 60s 4ms/step - loss: 0.1532 - accuracy: 0.9491
# Epoch 33/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1520 - accuracy: 0.9493
# Epoch 34/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1513 - accuracy: 0.9494
# Epoch 35/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1506 - accuracy: 0.9498
# Epoch 36/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1496 - accuracy: 0.9502
# Epoch 37/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1489 - accuracy: 0.9503
# Epoch 38/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1474 - accuracy: 0.9508
# Epoch 39/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1469 - accuracy: 0.9507
# Epoch 40/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1459 - accuracy: 0.9511
# Epoch 41/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1455 - accuracy: 0.9513
# Epoch 42/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1446 - accuracy: 0.9515
# Epoch 43/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1441 - accuracy: 0.9517
# Epoch 44/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1432 - accuracy: 0.9519
# Epoch 45/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1430 - accuracy: 0.9520
# Epoch 46/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1423 - accuracy: 0.9520
# Epoch 47/50
# 15709/15709 [==============================] - 61s 4ms/step - loss: 0.1420 - accuracy: 0.9523
# Epoch 48/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1407 - accuracy: 0.9525
# Epoch 49/50
# 15709/15709 [==============================] - 62s 4ms/step - loss: 0.1407 - accuracy: 0.9527
# Epoch 50/50
# 15709/15709 [==============================] - 63s 4ms/step - loss: 0.1405 - accuracy: 0.9528
# Evalute  LeNet5_model
# Evalute on train set
# 15709/15709 [==============================] - 44s 3ms/step - loss: 0.1293 - accuracy: 0.9558
# Evalute on test set
# 827/827 [==============================] - 2s 3ms/step - loss: 0.3155 - accuracy: 0.9277
